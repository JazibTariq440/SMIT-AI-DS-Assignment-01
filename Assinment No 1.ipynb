# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
# Write your code here
name = "Jazib Tariq"
print (name.upper())
# Out:
# JAZIB TARIQ

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
# Write your code here
fruit ='coconut'

# %%
print(len(fruit))
# Out:
# 7

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
# Write your code here
sentence = 'python is fun'
print(sentence.replace('fun','awesome'))
# Out:
# python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
# Write your code here
text = 'Hello World'
print(text.find('World'))
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
# Write your code here
email = "JaizbTariq440@gmail.com"
print(email.lower())
# Out:
# jaizbtariq440@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
# Write your code here
text = "python Programming"
print (text)
# Out:
#  python Programming

# %%
# Write your code here
text = " python Programming "
print (text.strip())
# Out:
# python Programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
# Write your code here
text = " Welcome to coding"
print(text.count('o'))
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
# Write your code here
age = input("My Age is")
age= int(age)
print (age)
# Out:
# My Age is 27
# 27

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
# Write your code here
number = 15.99
print(int(number))
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
# Write your code here
honda = input("Honda Bike is")
suzuki = input ("Suzuki Bike is")
honda = int(honda)
suzuki = int(suzuki)
print (honda + suzuki)
# Out:
# Honda Bike is 125
# Suzuki Bike is 150
# 275

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
# Write your code here
num = 100
num = str(num)
print (type(num))
# Out:
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
# Write your code here
price = float(input("Petrol price is"))
price = int(price)
print (price)
# Out:
# Petrol price is 99.5
# 99

# %%
# Write your code here
price = float(input("Petrol price is"))
price = int(price)

print ("Petrol price is", price)
# Out:
# Petrol price is 99.5
# Petrol price is 99

# %%
price = int(float(input("Petrol price is")))
print(f"Petrol price is {price}")
# Out:
# Petrol price is 99.5
# Petrol price is 99

# %%
price = int(float(input()))
print(f"Petrol price is {price}")
# Out:
#  99.5
# Petrol price is 99

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
# Write your code here
a = '10'
b = '20'

print (int(a) + int(b))
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
# Write your code here
num = '50.5'
num = float(num)
print (num + 10)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
# Write your code here
Name = input()
City = input ()
print(f"Hello {Name}, Welcome to {City}")
# Out:
#  Jazib
#  Karachi
# Hello Jazib, Welcome to Karachi

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
# Write your code here
Car_seats = int(input("car"))
Bike_seats = int(input("bike"))

print (Car_seats * Bike_seats)
# Out:
# car 4
# bike 2
# 8

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
# Write your code here
Colour = input ("Favorite colour: ")
print ("I also like", Colour)
# Out:
# Favorite colour:  Green
# I also like Green

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
# Write your code here
Birth_year = int(input("birth_year"))
current_year=2026

age = current_year - Birth_year

print ("I'm", age, "year old")
# Out:
# birth_year 1998
# I'm 28 year old

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
# Write your code here
word = input("enter word")
print (word * 5)
# Out:
# enter word Pakistan
# PakistanPakistanPakistanPakistanPakistan

# %%
# Write your code here
word = input("enter word")
print ((word + "\n") * 5)
# Out:
# enter word Pakistan
# Pakistan
# Pakistan
# Pakistan
# Pakistan
# Pakistan

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
# Write your code here
m_number = input ("enter number: ")
print (m_number, "is mobile number")
# Out:
# enter number:  090078601
# 090078601 is mobile number

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
# Write your code here
a = 10
b = 3

remainder = a % b

print ("modulo is", remainder)
# Out:
# modulo is 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
# Write your code here
number = 15
result = number > 10 and number < 20

print(result)
# Out:
# True

# %% [markdown]
# ## 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
# Write your code here
paisa = int(input("enter paisa"))
result = paisa > 100

print (result)
# Out:
# enter paisa 48
# False

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
# Write your code here
result = 2**5
print ("Answer is", result)
# Out:
# Answer is 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
# Write your code here
result = 50 == 100
print (result)
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
# Write your code here
a = True
b = False

result = a or b

print (result)
# Out:
# True

# %%
a = False
b = False

result = a or b

print (result)
# Out:
# False

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
# Write your code here
number = int(input("women number"))

if number >= 0:
    print ("positive_women")
else :
    print ("negative_women")
# Out:
# women number 4
# positive_women

# %%
number = int(input("women number"))

if number >= 0:
    print ("positive women")
else:
    print ("negative women")
# Out:
# women number -1
# negative women

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
# Write your code here
age = int(input("Voter age"))

if number >=18:
    print ("Eligible for vote")
else:
    print ("Not Eligble for vote")
# Out:
# Voter age 17
# Not Eligble for vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
# Write your code here
number = int(input("Any number"))

if number % 2 == 0:
    print ("Even Number")
else:
    print ("Odd Number")
# Out:
# Any number 7
# Odd Number

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
# Write your code here
Nasir = int(input("enter age"))
Tariq = int(input("enter age"))

if Nasir > Tariq:
    print("Nasir Elder")
elif Tariq > Nasir: 
    print ("Tariq Elder")
else:
    print ("Twin Brother")
# Out:
# enter age 45
# enter age 55
# Tariq Elder

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
# Write your code here
marks = int(input("Total Marks"))

if marks >= 33:
    print ("Pass")
else:
    print ("Fail")
# Out:
# Total Marks 45
# Pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
# Write your code here
text = input ("enter text")

if text != " ":
    print ("String is not empty", text)
else:
    print ("String is empty")
# Out:
# enter text Kallu Madari
# String is not empty Kallu Madari

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
# Write your code here
password = input("Enter password")

if password == "python123":
    print ("Acsess Granted")
else:
    print ("Wrong Password")
# Out:
# Enter password pythonHarami
# Wrong Password

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# Write your code here
number = int(input("Any number"))

if number == 0:
    print ("Null")
else:
    print ("Pani wala Null")
# Out:
# Any number 4
# Pani wala Null

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
# Write your code here
marks = int(input("enter marks"))

if marks >= 90:
    print ("Grade A")
elif marks >= 80:
    print ("Grade B")
elif marks >= 70:
    print ("Grade C")
else:
    print ("Grade D", "Nalaike Bacha")
# Out:
# enter marks 68
# Grade D Nalaike Bacha

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temperature = int(input("enter temperature"))

if temperature > 30:
    print ("Today is Hot")
elif temperature >= 15:
    print ("Today is Warm")
else:
    print ("Today is Cold")
# Out:
# enter temperature 41
# Today is Hot

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here
number = int(input("Any number"))

if number %3 == 0 and number %5 == 0:
    print ("FizzBuzz Divided by 3 & 5 both")
elif number %3 == 0:
    print ("Fizz Divided by 3")
elif number %5 == 0:
    print ("Buzz Divided by 5")
else:
    print ("Not Divided by 3 & 5 both")
# Out:
# Any number 44
# Not Divided by 3 & 5 both

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code here
Alphabet = input ("enter alphabet").lower()

if Alphabet in "aeiou":
    print ("Vowal")
else:
    print ("Not Vowel")
# Out:
# enter alphabet s
# Not Vowel

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
bill = float(input("Haram ka Paisa"))

if bill > 5000:
    discount = bill * 0.20
elif bill >= 2000:
    discount = bill * 0.10
else:
    discount = 0

Final_Bill = bill - discount

print ("Discount (Shukar)", discount)
print ("Final Bill(Haram Moth)", Final_Bill)
# Out:
# Haram ka Paisa 35000
# Discount (Shukar) 7000.0
# Final Bill(Haram Moth) 28000.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("enter age"))

if age <= 12:
    print ("Child/chota")
elif age <= 19:
    print ("Teenager/Chapatar")
elif age <= 59:
    print ("Adult/Pura")
else:
    print ("Senior Citizen/Near to Biryani")
# Out:
# enter age 60
# Senior Citizen/Near to Biryani

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here
year = int(input("enter year"))

if year % 4 == 0 and year % 100 != 0:
    print ("Leap Year")
else:
    print ("Not Leap Year")
# Out:
# enter year 1998
# Not Leap Year

# %%
year = int(input("enter year"))

if year % 4 == 0 and year % 100 != 0:
    print ("Leap Year")
else:
    print ("Not Leap Year")
# Out:
# enter year 2024
# Leap Year

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here
week = int(input("Week day (1-7): "))

if week == 1:
    print("Monday")
elif week == 2:
    print("Tuesday")
elif week == 3:
    print("Wednesday")
elif week == 4:
    print("Thursday")
elif week == 5:
    print("Friday")
elif week == 6:
    print("Saturday")
elif week == 7:
    print("Sunday")
else:
    print("Invalid week day")
# Out:
# Week day (1-7):  4
# Thursday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# Write your code here
a = float(input("Any number 1"))
b = float(input("Any number 2"))
op = input("Oprerator (+,-,*,/): ")

if op == "+":
    print ("Result", a + b)
elif op == "-":
    print ("Result", a - b)
elif op == "*":
    print ("Result", a * b)
elif op == "/":
    if b != 0:
        print ("Result", a / b)
    else:
        print ("Not divided by Zero")
else :
    print ("Invalid Operator")
# Out:
# Any number 1 44
# Any number 2 24
# Oprerator (+,-,*,/):  /
# Result 1.8333333333333333

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float(input("weight in KG"))
height = float(input("height in Meters"))

BMI = height / (height ** 2)

print ("BMI is", round(BMI, 2))

if BMI < 40:
    print ("Suki Haddi Under weight")
elif BMI < 65:
    print ("Fit Bacha Normal weight")
else:
    print ("Hati ka Bacha Over weight")
# Out:
# weight in KG 68
# height in Meters 1.92
# BMI is 0.52
# Suki Haddi Under weight

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
# Write your code here
correct_pin = 1234
balance = 50000

pin = int(input("Enter your pin: "))

if pin == correct_pin:
    print("Pin is Correct")

    amount = float(input("Enter your amount: "))

    if amount <= balance:
        print("Withdrawal successful")

        balance = balance - amount
        print("Remaining balance:", balance)

    else:
        print("Insufficient balance")

else:
    print("Wrong Pin")
# Out:
# Enter your pin:  1234
# Pin is Correct
# Enter your amount:  44000
# Withdrawal successful
# Remaining balance: 6000.0

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
# Write your code here
correct_username = "SMIT ka Lounda"
correct_password = "420+420"

username = input("enter your username")

if username == correct_username:

    password = input ("enter your password")

    if password == correct_password:
        print ("Login Successful")

    else :
        print ("Wrong Password")

else:
    print ("Wrong Username")
# Out:
# enter your username SMIT ka Lounda
# enter your password 420=420
# Wrong Password

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
num1 = int(input("num"))
num2 = int(input("num"))
num3 = int(input("num"))

if num1 > num2:

    if num1 > num3:
        print ("Large number is", num1)
    else:
        print ("Large number is", num2)


else:


    if num2 > num3:
        print ("Large number is", num2)
    else:
        print ("Large number is", num3)
# Out:
# num 84
# num 78
# num 24
# Large number is 84

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
# Write your code here
age = int(input("enter your age"))

if age >= 18:

    id_card = input("Do you have I.D? (yes/no")

    if id_card == "yes":
        print ("Ticket Issued")
    else:
        print ("I.D card Required")

else: 
    print ("You are under 18")
# Out:
# enter your age 27
# Do you have I.D? (yes/no yes
# Ticket Issued

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
marks = int(input("enter you marks"))

if marks >= 80:

    interview = input("Interview clear? (yes/no)")

    if interview == "yes":
        print ("Admission Done")
    else:
        print ("Interview Not Cleared")

else:
    print ("Marks are enough to admission")
# Out:
# enter you marks 78
# Marks are enough to admission

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
number = int(input("Enter a number"))

if number >= 0:

    if number >100:
        print ("Number is positive & greater than 100")
    else:
        print ("Number is positive & less than 100")

else :
    Print ("Number is negative")
# Out:
# Enter a number 84
# Number is positive & less than 100

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
# Write your code here
order_type = input("Veg ya Non-Veg? (veg/non-veg)")

if order_type == "veg":

    veg_item = input("Choose: Paneer or dal")

    if veg_item == "Paneer":
        print ("You order Paneer")
    elif veg_item == "Dal":
        print ("You order Dal")
    else:
        print ("Invalid Veg Option")

elif order_type == "non-veg":

    nonveg_item = input("Choose: Chicken or Mutton")

    if nonveg_item == "Chicken":
        print ("You order Chicken")
    elif nonveg_item == "Mutton":
        print ("You order Mutton")
    else:
        print ("Invalid Non-veg Option")

else:
    print ("Invalid order type")
# Out:
# Veg ya Non-Veg? (veg/non-veg) veg
# Choose: Paneer or dal Paneer
# You order Paneer

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
number = int(input("enter a number"))

if number >= -9 and number <= 9:
    print ("Number is single digit")
elif number >= -99 and number <= 99:
    print ("Number is double digit")
elif number >= -999 and number <= 999:
    print ("Number is triple digit")

else: 
    print ("Number is more than triple digit")
# Out:
# enter a number 104
# Number is triple digit

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
salary = float(input("enter a salary"))
years = int(input("enter a servies years"))

if years >5:

    bonus = salary * 0.05
    final_salary = salary + bonus

    print ("bonus", bonus)
    print ("Final Salary", final_salary)

else:
    print ("No bonus, remains salary", salary)
# Out:
# enter a salary 50000
# enter a servies years 6
# bonus 2500.0
# Final Salary 52500.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
# Write your code here
a = float(input("Enter side 1: "))
b = float(input("Enter side 2: "))
c = float(input("Enter side 3: "))

if a == b and b == c:
    print("Equilateral Triangle")

elif a == b or b == c or a == c:
    print("Isosceles Triangle")

else:
    print("Scalene Triangle")
# Out:
# Enter side 1:  9.2
# Enter side 2:  8.4
# Enter side 3:  9.9
# Scalene Triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
# Write your code here
month = input("Enter month name: ")

if month == "january":
    print("31 days")

elif month == "february":
    print("28 or 29 days (leap year)")

elif month == "march":
    print("31 days")

elif month == "april":
    print("30 days")

elif month == "may":
    print("31 days")

elif month == "june":
    print("30 days")

elif month == "july":
    print("31 days")

elif month == "august":
    print("31 days")

elif month == "september":
    print("30 days")

elif month == "october":
    print("31 days")

elif month == "november":
    print("30 days")

elif month == "december":
    print("31 days")

else:
    print("Invalid month name")
# Out:
# Enter month name:  july
# 31 days

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here
num = int(input("Enter a number: "))

if num % 2 == 0:

    if num > 50:
        print("Even number and greater than 50")
    else:
        print("Even number and less than or equal to 50")

else:
    print("Number is Odd")
# Out:
# Enter a number:  54
# Even number and greater than 50

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

if maths >= 40 and science >= 40:
    print("Pass")

else:
    print("Fail")
    
    if maths < 40 and science < 40:
        print("Both subjects are weak")
    elif maths < 40:
        print("Maths is weak")
    else:
        print("Science is weak")
# Out:
# Enter Maths marks:  39
# Enter Science marks:  68
# Fail
# Maths is weak

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
units = int(input("Enter electricity units: "))

bill = 0

if units <= 100:
    bill = 0

elif units <= 200:
    bill = (units - 100) * 5

else:
    bill = (100 * 5) + (units - 200) * 10

print("Total Bill:", bill)
# Out:
# Enter electricity units:  192
# Total Bill: 460

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
score = int(input("Enter your score: "))

if score <= 50:
    print("Beginner Level")

elif score <= 100:
    print("Intermediate Level")
    
    boss = input("Did you complete boss level? (yes/no): ")
    
    if boss == "yes":
        print("Boss Level Completed")
    else:
        print("Boss Level Not Completed")

else:
    print("Advanced Level")
# Out:
# Enter your score:  84
# Intermediate Level
# Did you complete boss level? (yes/no):  yes
# Boss Level Completed

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
correct_username = "Ali BABA"
correct_password = "@40Chor"
correct_security_answer = "Khol ga Sim Sim"

username = input("Enter username: ")

if username == correct_username:

    password = input("Enter password: ")

    if password == correct_password:

        security = input("What is your code")

        if security == correct_security_answer:
            print("Login Successful")
        else:
            print("Wrong Security code")

    else:
        print("Wrong Password")

else:
    print("Wrong Username")
# Out:
# Enter username:  Ali BABA
# Enter password:  @40Chor
# What is your code Khol ga Sim Sim
# Login Successful
